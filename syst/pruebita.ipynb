# %%
from CCS200 import CCS200
c = CCS200()
print(c.init())
print(c.setIntegrationTime(0.01))
data = []
for i in range(10):
    print(c.startScanExtTrg())
    print(c.getDeviceStatus())
    d = c.getScanData()
    data.append(d)
    print(c.close())

from pylab import *
for i in data:
#plot(np.linspace(1.927816925e+002,1.023623779e+003,len(i))[::-1],i)
    plot(i)
    show(0)
# Out:
# init> 0 b'The status code passed to the operation could not be interpreted.'
# b'\x11'
# setIntegrationTime> 0 b'The status code passed to the operation could not be interpreted.'
# b'\x0e'
# startScanExtTrg> 0 b'The status code passed to the operation could not be interpreted.'
# b'\x0e'
# getDeviceStatus> 0 b'The status code passed to the operation could not be interpreted.'
# 0
# getScanData> 0 b'The status code passed to the operation could not be interpreted.'
# b'\x00'
# startScanExtTrg> 0 b'The status code passed to the operation could not be interpreted.'
# b'\x0e'
# getDeviceStatus> 0 b'The status code passed to the operation could not be interpreted.'
# 0
# getScanData> 0 b'The status code passed to the operation could not be interpreted.'
# b'\x00'
# startScanExtTrg> 0 b'The status code passed to the operation could not be interpreted.'
# b'\x0e'
# getDeviceStatus> 0 b'The status code passed to the operation could not be interpreted.'
# 0
# getScanData> 0 b'The status code passed to the operation could not be interpreted.'
# b'\x00'
# startScanExtTrg> 0 b'The status code passed to the operation could not be interpreted.'
# b'\x0e'
# getDeviceStatus> 0 b'The status code passed to the operation could not be interpreted.'
# 0
# getScanData> 0 b'The status code passed to the operation could not be interpreted.'
# b'\x00'
# startScanExtTrg> 0 b'The status code passed to the operation could not be interpreted.'
# b'\x0e'
# getDeviceStatus> 0 b'The status code passed to the operation could not be interpreted.'
# 0
# getScanData> 0 b'The status code passed to the operation could not be interpreted.'
# b'\x00'
# startScanExtTrg> 0 b'The status code passed to the operation could not be interpreted.'
# b'\x0e'
# getDeviceStatus> 0 b'The status code passed to the operation could not be interpreted.'
# 0
# getScanData> 0 b'The status code passed to the operation could not be interpreted.'
# b'\x00'
# startScanExtTrg> 0 b'The status code passed to the operation could not be interpreted.'
# b'\x0e'
# getDeviceStatus> 0 b'The status code passed to the operation could not be interpreted.'
# 0
# getScanData> 0 b'The status code passed to the operation could not be interpreted.'
# b'\x00'
# startScanExtTrg> 0 b'The status code passed to the operation could not be interpreted.'
# b'\x0e'
# getDeviceStatus> 0 b'The status code passed to the operation could not be interpreted.'
# 0
# getScanData> 0 b'The status code passed to the operation could not be interpreted.'
# b'\x00'
# startScanExtTrg> 0 b'The status code passed to the operation could not be interpreted.'
# b'\x0e'
# getDeviceStatus> 0 b'The status code passed to the operation could not be interpreted.'
# 0
# getScanData> 0 b'The status code passed to the operation could not be interpreted.'
# b'\x00'
# startScanExtTrg> 0 b'The status code passed to the operation could not be interpreted.'
# b'\x0e'
# getDeviceStatus> 0 b'The status code passed to the operation could not be interpreted.'
# 0
# getScanData> 0 b'The status code passed to the operation could not be interpreted.'
# b'\x00'

# %%
c.close()
# Out:
# b'\x00'
